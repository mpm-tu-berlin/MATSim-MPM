# %%
import pandas as pd

df = pd.read_csv("../data/hdv_2023_missionprofile/hdv_2023_missionprofile.csv", sep=";")
df.head()
# Out:
# C:\Users\Tobias\AppData\Local\Temp\ipykernel_15988\842558009.py:3: DtypeWarning: Columns (0: ResultType, 1: TotalVehicleMass_unit, 2: PrimaryVehicleSubgroup, 3: ActualChargeDepletingRange_unit, 4: EquivalentAllElectricRange_unit, 5: ZeroCO2EmissionRange_unit, 6: AverageAxlegearEfficiency_unit, 7: AverageDrivingSpeed_unit, 8: AverageGearboxEfficiency_unit, 9: EngineSpeedDriving_Average_unit, 10: EngineSpeedDriving_Max_unit, 11: EngineSpeedDriving_Min_unit, 12: MaxSpeed_unit, 13: FC_AuxHeater_FuelType) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/hdv_2023_missionprofile/hdv_2023_missionprofile.csv", sep=";")
#                                           vehicle_id                Mission  \
# 0  0x2F9CEFD6AA9A66642C202024396C902C0466D5E3A77C...  Regional delivery EMS
# 1  0x631E2B99D35D4EE4A7C8C7611C7F0ED6208A0A640A28...  Regional delivery EMS
# 2  0x6305D44E3573947462AC690BED2CC5FE3B750600EBBE...  Regional delivery EMS
# ...
